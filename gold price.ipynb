# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Importing the dataset

# %%
data=pd.read_csv('Gold price dataset.csv')

# %%
data
# Out:
#       Sl.no        Date         Open         High          Low        Close  \
# 0         1  30-08-2000   273.899994   273.899994   273.899994   273.899994
# 1         2  31-08-2000   274.799988   278.299988   274.799988   278.299988
# 2         3  01-09-2000   277.000000   277.000000   277.000000   277.000000
# 3         4  05-09-2000   275.799988   275.799988   275.799988   275.799988
# 4         5  06-09-2000   274.200012   274.200012   274.200012   274.200012
# ...     ...         ...          ...          ...          ...          ...
# 5674   5675  12-04-2023  2005.199951  2025.699951  2005.199951  2010.900024
# 5675   5676  13-04-2023  2015.599976  2048.600098  2015.599976  2041.300049
# 5676   5677  14-04-2023  2041.000000  2047.800049  1995.000000  2002.199951
# 5677   5678  17-04-2023  2002.699951  2007.599976  1983.199951  1994.199951
# 5678   5679  18-04-2023  2007.900024  2014.400024  2005.599976  2012.099976
#
#         Adj Close  Volume
# 0      273.899994       0
# 1      278.299988       0
# 2      277.000000       0
# 3      275.799988       2
# 4      274.200012       0
# ...           ...     ...
# 5674  2010.900024     172
# 5675  2041.300049    1043
# 5676  2002.199951     718
# 5677  1994.199951     718
# 5678  2012.099976   25096
#
# [5679 rows x 8 columns]

# %% [markdown]
# # Data Preprocessing

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5679 entries, 0 to 5678
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Sl.no      5679 non-null   int64
#  1   Date       5679 non-null   object
#  2   Open       5679 non-null   float64
#  3   High       5679 non-null   float64
#  4   Low        5679 non-null   float64
#  5   Close      5679 non-null   float64
#  6   Adj Close  5679 non-null   float64
#  7   Volume     5679 non-null   int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 355.1+ KB

# %%
data.head()
# Out:
#    Sl.no        Date        Open        High         Low       Close  \
# 0      1  30-08-2000  273.899994  273.899994  273.899994  273.899994
# 1      2  31-08-2000  274.799988  278.299988  274.799988  278.299988
# 2      3  01-09-2000  277.000000  277.000000  277.000000  277.000000
# 3      4  05-09-2000  275.799988  275.799988  275.799988  275.799988
# 4      5  06-09-2000  274.200012  274.200012  274.200012  274.200012
#
#     Adj Close  Volume
# 0  273.899994       0
# 1  278.299988       0
# 2  277.000000       0
# 3  275.799988       2
# 4  274.200012       0

# %%
data.tail()
# Out:
#       Sl.no        Date         Open         High          Low        Close  \
# 5674   5675  12-04-2023  2005.199951  2025.699951  2005.199951  2010.900024
# 5675   5676  13-04-2023  2015.599976  2048.600098  2015.599976  2041.300049
# 5676   5677  14-04-2023  2041.000000  2047.800049  1995.000000  2002.199951
# 5677   5678  17-04-2023  2002.699951  2007.599976  1983.199951  1994.199951
# 5678   5679  18-04-2023  2007.900024  2014.400024  2005.599976  2012.099976
#
#         Adj Close  Volume
# 5674  2010.900024     172
# 5675  2041.300049    1043
# 5676  2002.199951     718
# 5677  1994.199951     718
# 5678  2012.099976   25096

# %%
data.shape
# Out:
# (5679, 8)

# %%
data.describe()
# Out:
#              Sl.no         Open         High          Low        Close  \
# count  5679.000000  5679.000000  5679.000000  5679.000000  5679.000000
# mean   2840.000000  1082.018595  1087.466456  1076.254763  1081.929001
# std    1639.530421   516.988719   520.004219   513.781155   516.931497
# min       1.000000   255.000000   256.100006   255.000000   255.100006
# 25%    1420.500000   587.299988   589.250000   585.850006   587.200012
# 50%    2840.000000  1208.900024  1214.800049  1202.800049  1208.900024
# 75%    4259.500000  1469.099976  1475.700012  1461.850036  1469.100036
# max    5679.000000  2053.600098  2072.000000  2040.000000  2051.500000
#
#          Adj Close         Volume
# count  5679.000000    5679.000000
# mean   1081.929001    4293.552738
# std     516.931497   24419.400217
# min     255.100006       0.000000
# 25%     587.200012      20.000000
# 50%    1208.900024     102.000000
# 75%    1469.100036     393.000000
# max    2051.500000  386334.000000

# %% [markdown]
# # Missing values

# %%
data.isnull().sum()
# Out:
# Sl.no        0
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# # Correlation Analysis

# %%
correlation=data.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## creating heatmap
sns.heatmap(correlation,cmap='plasma',center=0,annot=True)
# Out:
# <AxesSubplot:>

# %%
data['Date'].value_counts()
# Out:
# 30-08-2000    1
# 18-11-2015    1
# 15-10-2015    1
# 14-10-2015    1
# 13-10-2015    1
#              ..
# 01-04-2008    1
# 31-03-2008    1
# 28-03-2008    1
# 27-03-2008    1
# 18-04-2023    1
# Name: Date, Length: 5679, dtype: int64

# %%
import plotly.express as px
import matplotlib.pyplot as plt

# %%
# plot price of gold for each increasing day
data["Open"].plot()
plt.title("Change in price of gold through date")
plt.xlabel("Date")
plt.ylabel("Open")
plt.show()

# %% [markdown]
# # Splitting X and Y into taining and testing varaibles

# %%
X=data[['Open','High','Low']]
y=data['Close']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25)

# %%
X_train.shape,X_test.shape
# Out:
# ((4259, 3), (1420, 3))

# %%
y_train.shape,y_test.shape
# Out:
# ((4259,), (1420,))

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

# %%
regressor = RandomForestRegressor(n_estimators=100)

# %%
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
# prediction on Test Data
test_data_prediction = regressor.predict(X_test)

# %%
print(test_data_prediction)
# Out:
# [ 402.02800567 1756.35402955  736.40000305 ...  652.26798341 1271.96900134
#  1667.08299074]

# %%
# R squared errorY
error_score = metrics.r2_score(y_test, test_data_prediction)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.9998767821105093

# %%
y_test=list(y_test)

# %%
plt.plot(y_test, color='blue', label = 'Actual Value')
plt.plot(test_data_prediction, color='green', label='Predicted Value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('GLD Price')
plt.legend()
plt.show()

# %% [markdown]
# # Training the model using linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
# Visualize the actual vs predicted prices
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('Actual vs Predicted Stock Prices')
plt.xlabel('Sample Index')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
reg=LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
prediction=reg.predict(X)

# %%
prediction
# Out:
# array([ 273.9508941 ,  277.50046425,  277.05179913, ..., 2010.80838221,
#        1991.74180624, 2011.57875231])

# %% [markdown]
# # Prediction using own data

# %%
reg.predict([['4582','879562','45121']])
# Out:
# D:\New folder\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# D:\New folder\lib\site-packages\sklearn\base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# array([698536.97616629])

# %%
data['Close_pred']=prediction

# %%
X_test.columns
# Out:
# Index(['Open', 'High', 'Low'], dtype='object')

# %% [markdown]
# # Calculating the MSE

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(data['Close'],data['Close_pred'])
mse
# Out:
# 21.20748853626084

# %%
Open=float(input("enter a value"))
High=float(input("enter a value"))
Low=float(input("enter a value"))

data = np.array([[Open,High,Low]])
pred_value = model.predict(data)[0]

print(pred_value)
# Out:
# enter a value7852.02
# enter a value745220.4
# enter a value7854.02
# 560798.2180198528
# D:\New folder\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pickle
file=open("model.pkl",'wb')
pickle.dump(model,file)
